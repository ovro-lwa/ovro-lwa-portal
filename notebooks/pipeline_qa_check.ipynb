# %% [markdown]
# # Pipeline QA check (JupyterLab)
#
# Interactive dashboard for one observation day: scan finds available days,
# select a day to load the thermal-noise QA grid, hybrid flux ratio heatmaps
# (imfit / model from `flux_check_hybrid.csv`), and Stokes I/V zenith review
# (automatic when QA Zarr exists). Use **Convert FITS → Zarr** when Zarr is missing.
#
# For tree-wide coverage summaries, see `pipeline_coverage_summary.ipynb`.

# %%
import panel as pn

from ovro_lwa_portal.viz.pipeline_qa_app import display_pipeline_qa_app

pn.extension()
display_pipeline_qa_app()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
# ...
