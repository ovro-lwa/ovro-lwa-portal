# %% [markdown]
# # Pipeline QA check — phase2 (JupyterLab)
#
# Interactive dashboard for one **phase2** observation day under
# `/lustre/pipeline/exopipe/phase2/`. Runs live in `Science_*` directories (not `Run_*`).
#
# Per run:
#
# - **Thermal noise:** single plot at `QA/*_thermal_noise_vs_freq.png` (not a subband grid).
# - **Flux ratios:** Bokeh heatmaps from `QA/*_flux_check_hybrid.csv` (one CSV per run).
# - **Dewarp summary:** LST × frequency heatmap from `QA/*dewarp_summary.csv` (`freq_mhz`, `median_shift_arcmin`).
# - **Stokes review:** dewarped FITS (`*I-NoTaper-*-Robust-0-*` / `*V-Taper-*-Robust-0-*`
#   `image.pbcorr_dewarped.fits`) converted to QA Zarr when missing.
#
# Phase1 Wideband products: `pipeline_qa_check_phase1.ipynb`.

# %%
from pathlib import Path

from ovro_lwa_portal.viz.pipeline_qa import PipelineQAConfig

# Edit these before running the dashboard.
PIPELINE_ROOT = Path("/lustre/pipeline/exopipe/phase2/")
SYMLINK_ROOT = Path("/lustre/claw")
ZARR_ROOT = Path("/fast/claw")
I_FITS_GLOB = "*I-NoTaper-*-Robust-0-*-image.pbcorr_dewarped.fits"
V_FITS_GLOB = "*V-Taper-*-Robust-0-*-image.pbcorr_dewarped.fits"
RUN_DIR_PREFIX = "Science_"
RUN_DIR_PATTERN = r"Science_(\d{8})_(\d{6})"
QA_THERMAL_NOISE_GLOB = "QA/*_thermal_noise_vs_freq.png"
FLUX_CHECK_CSV_GLOB = "QA/*_flux_check_hybrid.csv"
# Distinct from phase1 Zarr names; none should exist until you convert FITS → Zarr.
I_QA_ZARR_STEM = "pipelineQA-phase2-I-NoTaper-Robust-0"
V_QA_ZARR_STEM = "pipelineQA-phase2-V-Taper-Robust-0"

QA_CONFIG = PipelineQAConfig(
    pipeline_root=PIPELINE_ROOT,
    symlink_root=SYMLINK_ROOT,
    zarr_root=ZARR_ROOT,
    i_fits_glob=I_FITS_GLOB,
    v_fits_glob=V_FITS_GLOB,
    run_dir_prefix=RUN_DIR_PREFIX,
    run_dir_pattern=RUN_DIR_PATTERN,
    qa_thermal_noise_glob=QA_THERMAL_NOISE_GLOB,
    flux_check_csv_glob=FLUX_CHECK_CSV_GLOB,
    flux_check_csv_per_run=True,
    i_qa_zarr_stem=I_QA_ZARR_STEM,
    v_qa_zarr_stem=V_QA_ZARR_STEM,
    thermal_noise_grid_cols=4,
    dewarp_summary_csv_glob="QA/*dewarp_summary.csv",
    thermal_noise_plot_name="thermal_noise_vs_freq",
    qa_run_label="Science",
)

# %%
import panel as pn

from ovro_lwa_portal.viz.pipeline_qa_app import display_pipeline_qa_app

pn.extension("tabulator")
display_pipeline_qa_app(qa_config=QA_CONFIG)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='051e2525-20ef-4a9c-82a7-1cb4918a39b0'>
#   <div id="da89ed96-2ada-4e23-83b6-dee942a30dd7" data-root-id="051e2525-20ef-4a9c-82a7-1cb4918a39b0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"31642265-88bb-4ae5-b569-b928b7d2f4ac":{"version":"3.9.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"a7518932-6da3-42e6-943d-5714f261fc11","attributes":{"notifications":{"type":"object","name":"Notifications","id":"9b30316e-e48b-4644-bdb3-3bfd0d0af603"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"051e2525-20ef-4a9c-82a7-1cb4918a39b0"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"2f067875-ba52-4ebf-b9af-cc1bc324bd2f","attributes":{"plot_id":"051e2525-20ef-4a9c-82a7-1cb4918a39b0","comm_id":"1ff1ed2073d6423e906f57f60d6b260c","client_comm_id":"d8253d5ddac843b1b318b06f151ad3f5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"31642265-88bb-4ae5-b569-b928b7d2f4ac","roots":{"051e2525-20ef-4a9c-82a7-1cb4918a39b0":"da89ed96-2ada-4e23-83b6-dee942a30dd7"},"root_ids":["051e2525-20ef-4a9c-82a7-1cb4918a39b0"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Column(sizing_mode='stretch_width')
#     [0] Markdown(str)
#     [1] Row(sizing_mode='stretch_width')
#         [0] Select(label='Observation day', name='Observation day', width=220)
#         [1] Button(button_type='primary', color='primary', disabled=True, label='Convert FITS → Zarr', name='Convert FITS → Zarr')
#     [2] Column(sizing_mode='stretch_width')
#         [0] Markdown(str)
#         [1] IPyWidget(HTML, height=150, sizing_mode='stretch_width')
#     [3] ParamMethod(method, _pane=Spacer, defer_load=False, sizing_mode='stretch_width')
#     [4] Markdown(str)
#     [5] Row(sizing_mode='stretch_width')
#         [0] Button(disabled=True, label='Reload zenith panels', name='Reload zenith panels')
#     [6] Column(sizing_mode='stretch_width')
#         [0] Markdown(str)
#         [1] Row(sizing_mode='stretch_width', visible=False)
#             [0] LoadingSpinner(label='Loading zenith panels', name='Loading zenith panels', size=40)
#             [1] Markdown(str)
#         [2] Row(margin=(0, 0, 4, 0), max_width=1048, sizing_mode='stretch_width', visible=False)
#             [0] Markdown(str, margin=(0, 8, 0, 0), sizing_mode='fixed', width=520)
#             [1] Markdown(str, margin=(0, 0, 0, 0), sizing_mode='fixed', width=520)
#         [3] Row(sizing_mode='stretch_width')
#             [0] Column(margin=(0, 8, 0, 0), sizing_mode='fixed', width=520)
#                 [0] Markdown(str)
#                 [1] Column(sizing_mode='fixed', width=520)
#                     [0] Markdown(str)
#             [1] Column(margin=(0, 0, 0, 0), sizing_mode='fixed', width=520)
#                 [0] Markdown(str)
#                 [1] Column(sizing_mode='fixed', width=520)
#                     [0] Markdown(str)
#         [4] Column(max_width=1048, sizing_mode='stretch_width')
#             [0] Row(max_width=1048, sizing_mode='stretch_width', visible=False)
#                 [0] IntSlider(end=0, label='Time index', name='Time index', width=400)
#                 [1] IntSlider(end=0, label='Frequency index', name='Frequency index', width=400)
#                 [2] RadioButtonGroup(description='Stokes parameter f..., label='Sky view', name='Sky view', options={'Stokes I': 'I', ...}, value='I', width=200)
#             [1] Row(margin=(0, 0, 4, 0), max_width=1048, sizing_mode='stretch_width')
#                 [0] LoadingSpinner(size=20)
#                 [1] Markdown(str, sizing_mode='stretch_width')
#             [2] Alert(None, alert_type='danger', max_width=1048, sizing_mode='stretch_width', visible=False)
#             [3] IPyWidget(VBox, height=622, margin=(0, 0, 0, 0), sizing_mode='fixed', width=1048)
#     [7] Markdown(str)
#     [8] Column(sizing_mode='stretch_width')
#         [0] Markdown(str)
#     [9] Markdown(str)
#     [10] Column(sizing_mode='stretch_width')
#         [0] Markdown(str)
#     [11] Column(sizing_mode='stretch_width')
# PipelineQAApp(converting=False, error_message='', loading_day=False, loading_zenith=False, log_text='', name='PipelineQAApp00256', scanning=True, select_day=None)
# WARNING:param.Bokeh: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Row: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Bokeh: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Row: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Bokeh: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Row: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Bokeh: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Row: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Bokeh: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Row: Providing a width-responsive sizing_mode ('scale_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 18MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 18MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 18MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 23MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 23MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 23MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 27MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 27MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 27MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 32MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 32MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 32MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 36MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 36MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 36MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 41MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 41MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 41MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 46MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 46MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 46MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 50MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 50MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 50MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 55MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 55MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 55MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 59MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 59MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 59MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 64MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 64MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 64MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 69MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 69MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 69MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 73MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 73MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 73MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 78MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 78MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 78MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 82MHz-V-Taper-3591s-Robust-0-20250817_063920-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 82MHz-V-Taper-3591s-Robust-0-20250817_073911-image.pbcorr_dewarped.fits: time-from-filename
# WARNING:ovro_lwa_portal.fits_to_zarr_xradio:Using fallback metadata for 82MHz-V-Taper-3591s-Robust-0-20250817_083902-image.pbcorr_dewarped.fits: time-from-filename
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.298162 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.339725 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-END to 60904.381289 from DATE-END'.
